# %%
import pandas as pd

# %%
distances = []

for i in range(0,22):
    if(data['rows'][0]['elements'][i]['status']=='ZERO_RESULTS'):
        distances.append(data['rows'][i]['elements'][i]['status'])
    else:
        distance = round(data['rows'][0]['elements'][i]['duration']['value']/60)
        distances.append(distance)

df_distance = pd.DataFrame(distances)
df_distance.to_csv('1.csv')

# %%
x = pd.read_csv('list.csv')
x = x['District']

# %%
x
# Out:
# 0                Arbutus-Ridge
# 1                     Downtown
# 2            Dunbar-Southlands
# 3            Downtown Eastside
# 4                     Fairview
# 5           Grandview-Woodland
# 6             Hastings-Sunrise
# 7     Kensington-Cedar Cottage
# 8                   Kerrisdale
# 9                    Killarney
# 10                   Kitsilano
# 11                     Marpole
# 12              Mount Pleasant
# 13                    Oakridge
# 14         Renfrew-Collingwood
# 15                  Riley Park
# 16                 Shaughnessy
# 17                South Cambie
# 18                  Strathcona
# 19                      Sunset
# 20         Victoria-Fraserview
# 21                    West End
# 22             West Point Grey
# Name: District, dtype: object

# %%
import pandas as pd
import numpy as np

areas = ['Arbutus-Ridge,%20Vancouver|',
 'Downtown,%20Vancouver|',
 'Downtown%20Eastside,%20Vancouver|',
 'Dunbar-Southlands,%20Vancouver|',
 'Fairview,%20Vancouver|',
 'Grandview-Woodland,%20Vancouver|',
 'Hastings-Sunrise,%20Vancouver|',
 'Kensington-Cedar%20Cottage,%20Vancouver|',
 'Kerrisdale,%20Vancouver|',
 'Killarney,%20Vancouver|',
 'Kitsilano,%20Vancouver|',
 'Marpole,%20Vancouver|',
 'Mount%20Pleasant,%20Vancouver|',
 'Oakridge,%20Vancouver|',
 'Renfrew-Collingwood,%20Vancouver|',
 'Riley%20Park,%20Vancouver|',
 'Shaughnessy,%20Vancouver|',
 'South%20Cambie,%20Vancouver|',
 'Strathcona,%20Vancouver|',
 'Sunset,%20Vancouver|',
 'Victoria-Fraserview,%20Vancouver|',
 'West%20End,%20Vancouver|',
 'West%20Point%20Grey,%20Vancouver|']

# %%
def url_maker(areas, mode):
    temp_areas = areas
    urls = []
    x = "".join(temp_areas)
    for area in areas:
        url = "https://maps.googleapis.com/maps/api/distancematrix/"\
              "json?origins=" + str(area) +""\
              "&destinations=" + x + ""\
              "&units=metric"\
              "&mode=" + str(mode)+""\
              "&key=AIzaSyB1h8cmS0_6jkHKRekjoXghIugejRy1QIQ"
        urls.append(url)
    return urls

# %%
urls = url_maker(areas,'bicycling')

# %%
def url_fetcher():
    import requests
    import json

    #url = "https://maps.googleapis.com/maps/api/distancematrix/json?origins=Arbutus-Ridge,%20Vancouver|&destinations=Arbutus-Ridge,%20Vancouver|Downtown,%20Vancouver|Dunbar-Southlands,%20Vancouver|Fairview,%20Vancouver|Grandview-Woodland,%20Vancouver|Hastings-Sunrise,%20Vancouver|Kensington-Cedar%20Cottage,%20Vancouver|Kerrisdale,%20Vancouver|Killarney,%20Vancouver|Kitsilano,%20Vancouver|Marpole,%20Vancouver|Mount%20Pleasant,%20Vancouver|Oakridge,%20Vancouver|Renfrew-Collingwood,%20Vancouver|Riley%20Park,%20Vancouver|Shaughnessy,%20Vancouver|South%20Cambie,%20Vancouver|Strathcona,%20Vancouver|Sunset,%20Vancouver|Victoria-Fraserview,%20Vancouver|West%20End,%20Vancouver|West%20Point%20Grey,%20Vancouver|&units=metric&mode=transit&key=AIzaSyB1h8cmS0_6jkHKRekjoXghIugejRy1QIQ"

    full_responses = []
    for url in urls:
        payload={}
        headers = {}
        response = requests.request("GET", url, headers=headers, data=payload)
        wdata = response.text
        data = json.loads(wdata)
        full_responses.append(data)

    return full_responses

# %%
biking_response = url_fetcher()

# %%
biking_response
# Out:
# [{'destination_addresses': ['Arbutus Ridge, Vancouver, BC, Canada',
#    'Downtown Vancouver, Vancouver, BC, Canada',
#    'Downtown Eastside, Vancouver, BC, Canada',
#    'Dunbar-Southlands, Vancouver, BC V6S 1M6, Canada',
#    'Fairview, Vancouver, BC, Canada',
#    'Grandview-Woodland, Vancouver, BC, Canada',
#    'Hastings-Sunrise, Vancouver, BC, Canada',
#    'Kensington-Cedar Cottage, Vancouver, BC, Canada',
#    'Kerrisdale, Vancouver, BC, Canada',
#    'Killarney, Vancouver, BC, Canada',
#    'Kitsilano, Vancouver, BC, Canada',
#    'Marpole, Vancouver, BC, Canada',
#    'Mount Pleasant, Vancouver, BC, Canada',
#    'Oakridge, Vancouver, BC, Canada',
#    'Renfrew-Collingwood, Vancouver, BC, Canada',
#    'Riley Park–Little Mountain, Vancouver, BC, Canada',
#    'Shaughnessy, Vancouver, BC, Canada',
#    'South Cambie, Vancouver, BC, Canada',
#    'Strathcona, Vancouver, BC, Canada',
#    'Sunset, Vancouver, BC, Canada',
#    'Victoria-Fraserview, Vancouver, BC, Canada',
# ...

# %%
df = url_fetcher()
# Out:
# {'destination_addresses': ['Arbutus Ridge, Vancouver, BC, Canada', 'Downtown Vancouver, Vancouver, BC, Canada', 'Dunbar-Southlands, Vancouver, BC V6S 1M6, Canada', 'Fairview, Vancouver, BC, Canada', 'Grandview-Woodland, Vancouver, BC, Canada', 'Hastings-Sunrise, Vancouver, BC, Canada', 'Kensington-Cedar Cottage, Vancouver, BC, Canada', 'Kerrisdale, Vancouver, BC, Canada', 'Killarney, Vancouver, BC, Canada', 'Kitsilano, Vancouver, BC, Canada', 'Marpole, Vancouver, BC, Canada', 'Mount Pleasant, Vancouver, BC, Canada', 'Oakridge, Vancouver, BC, Canada', 'Renfrew-Collingwood, Vancouver, BC, Canada', 'Riley Park–Little Mountain, Vancouver, BC, Canada', 'Shaughnessy, Vancouver, BC, Canada', 'South Cambie, Vancouver, BC, Canada', 'Strathcona, Vancouver, BC, Canada', 'Sunset, Vancouver, BC, Canada', 'Victoria-Fraserview, Vancouver, BC, Canada', 'West End, Vancouver, BC, Canada', 'West Point Grey, Vancouver, BC, Canada'], 'origin_addresses': ['Arbutus Ridge, Vancouver, BC, Canada'], 'rows': [
# ...

# %%
df
# Out:
#     0
# 0  33
